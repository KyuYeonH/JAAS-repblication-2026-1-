# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.font_manager as fm

# 폰트 경로를 직접 지정 (터미널에서 찾은 경로를 넣기)
font_path = "/System/Library/Fonts/STHeiti Medium.ttc"  # 경로는 확인한 폰트에 맞게 수정!
font_prop = fm.FontProperties(fname=font_path)

# Matplotlib 기본 폰트 설정
plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

import os
os.chdir('/Users/kyuyeonhwang/Desktop/Dissertation/Data/ShortandLongregression')

# %%
df = pd.read_excel('stockflow.xlsx')

# %%
df.head()
# Out:
#    hd_flow_effect  hd_stock_effect    Time
# 0        0.385607       -14.941743  2007Q3
# 1        0.021539       -14.404123  2007Q4
# 2        0.128501       -14.326024  2008Q1
# 3        0.451354       -14.389903  2008Q2
# 4        0.251849       -14.521111  2008Q3

# %%
df['hd_stock_effect'] = df['hd_stock_effect']*0.1

fig1, ax1 = plt.subplots(figsize=(8,6), dpi=600)

# 왼쪽 Y축 (存量效果)
ax1.plot(df['Time'], df['hd_stock_effect'],
         color='blue', label='家庭负债存量效果')
ax1.set_ylabel('存量效果', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# 오른쪽 Y축 (流量效果)
ax2 = ax1.twinx()
ax2.plot(df['Time'], df['hd_flow_effect'],
         color='orange', label='家庭负债流量效果')
ax2.set_ylabel('流量效果', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# x축 라벨(분기) 간격 조정 (예: 4분기 단위로 표시)
tick_step = 4
tick_indices = np.arange(0, len(df), tick_step)
ax1.set_xticks(tick_indices)
ax1.set_xticklabels(df['Time'].iloc[tick_indices], rotation=45, ha='right')

tick_indices = np.linspace(0, len(df)-1, 10, dtype=int)
ax1.set_xticks(tick_indices)
ax1.set_xticklabels(df['Time'].iloc[tick_indices])

# 범례를 그래프 하단에 배치
fig1.legend(loc='lower center', bbox_to_anchor=(0.5, -0.1), ncol=2)

# 레이아웃 조정 (라벨이 겹치지 않도록)
plt.tight_layout()

plt.show()

# %%
dfc = pd.read_excel('cstockflow.xlsx')

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), dpi=400)  # 1행 2열 그래프 생성

# 첫 번째 그래프 (df 데이터)
ax1 = axes[0]
ax1.set_title("Impact of Household Debt on GDP Growth in China", fontsize=12)  # 첫 번째 그래프 소제목 추가
line1, = ax1.plot(df['Time'], df['hd_stock_effect'], color='blue', label='Flow Effect (Left)')
ax1.tick_params(axis='y', left=True, labelleft=True, colors='blue')  # 왼쪽 Y축 숫자 색상 변경

ax2 = ax1.twinx()  # 오른쪽 Y축 추가
line2, = ax2.plot(df['Time'], df['hd_flow_effect'], color='orange', label='Stock Effect (Right)')
ax2.tick_params(axis='y', right=True, labelright=True, colors='orange')  # 오른쪽 Y축 숫자 색상 변경

# x축 라벨 설정 (4분기 단위)
tick_step = 4
tick_indices = np.arange(0, len(df), tick_step)
ax1.set_xticks(tick_indices)
ax1.set_xticklabels(df['Time'].iloc[tick_indices], rotation=45, ha='right')

# 두 번째 그래프 (dfc 데이터)
ax3 = axes[1]
ax3.set_title("Impact of Household Debt on Consumption Growth in China", fontsize=12)  # 두 번째 그래프 소제목 추가
line3, = ax3.plot(dfc['Time'], dfc['hd_cstock_effect'], color='blue', label='Flow Effect (Left)')
ax3.tick_params(axis='y', left=True, labelleft=True, colors='blue')  # 왼쪽 Y축 숫자 색상 변경

ax4 = ax3.twinx()  # 오른쪽 Y축 추가
line4, = ax4.plot(dfc['Time'], dfc['hd_cflow_effect'], color='orange', label='Stock Effect (Right)')
ax4.tick_params(axis='y', right=True, labelright=True, colors='orange')  # 오른쪽 Y축 숫자 색상 변경

# x축 라벨 설정 (4분기 단위)
tick_indices = np.arange(0, len(dfc), tick_step)
ax3.set_xticks(tick_indices)
ax3.set_xticklabels(dfc['Time'].iloc[tick_indices], rotation=45, ha='right')

# 범례 설정 (선 색상 유지)
fig.legend([line1, line2], ['Stock Effect (Right)', 'Flow Effect (Left)'], loc='lower center', bbox_to_anchor=(0.5, -0.1), ncol=2, fontsize=14)

# 레이아웃 자동 조정
plt.tight_layout()
plt.show()
